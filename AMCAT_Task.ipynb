# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

Amcat_df = pd.read_csv('Amcatdata.csv')

Amcat_df
# Out:
#      Unnamed: 0      ID     Salary           DOJ           DOL  \
# 0         train  203097   420000.0   6/1/12 0:00       present
# 1         train  579905   500000.0   9/1/13 0:00       present
# 2         train  810601   325000.0   6/1/14 0:00       present
# 3         train  267447  1100000.0   7/1/11 0:00       present
# 4         train  343523   200000.0   3/1/14 0:00   3/1/15 0:00
# ...         ...     ...        ...           ...           ...
# 3993      train   47916   280000.0  10/1/11 0:00  10/1/12 0:00
# 3994      train  752781   100000.0   7/1/13 0:00   7/1/13 0:00
# 3995      train  355888   320000.0   7/1/13 0:00       present
# 3996      train  947111   200000.0   7/1/14 0:00   1/1/15 0:00
# 3997      train  324966   400000.0   2/1/13 0:00       present
#
#                       Designation           JobCity Gender           DOB  \
# 0         senior quality engineer         Bangalore      f  2/19/90 0:00
# ...

# %%
Amcat_df.shape
# Out:
# (3998, 39)

# %%
Amcat_df.describe()
# Out:
#                  ID        Salary  10percentage  12graduation  12percentage  \
# count  3.998000e+03  3.998000e+03   3998.000000   3998.000000   3998.000000
# mean   6.637945e+05  3.076998e+05     77.925443   2008.087544     74.466366
# std    3.632182e+05  2.127375e+05      9.850162      1.653599     10.999933
# min    1.124400e+04  3.500000e+04     43.000000   1995.000000     40.000000
# 25%    3.342842e+05  1.800000e+05     71.680000   2007.000000     66.000000
# 50%    6.396000e+05  3.000000e+05     79.150000   2008.000000     74.400000
# 75%    9.904800e+05  3.700000e+05     85.670000   2009.000000     82.600000
# max    1.298275e+06  4.000000e+06     97.760000   2013.000000     98.700000
#
#           CollegeID  CollegeTier   collegeGPA  CollegeCityID  CollegeCityTier  \
# count   3998.000000  3998.000000  3998.000000    3998.000000      3998.000000
# mean    5156.851426     1.925713    71.486171    5156.851426         0.300400
# ...

# %%
Amcat_df.isnull().sum()
# Out:
# Unnamed: 0               0
# ID                       0
# Salary                   0
# DOJ                      0
# DOL                      0
# Designation              0
# JobCity                  0
# Gender                   0
# DOB                      0
# 10percentage             0
# 10board                  0
# 12graduation             0
# 12percentage             0
# 12board                  0
# CollegeID                0
# CollegeTier              0
# Degree                   0
# Specialization           0
# collegeGPA               0
# CollegeCityID            0
# CollegeCityTier          0
# CollegeState             0
# GraduationYear           0
# English                  0
# Logical                  0
# Quant                    0
# Domain                   0
# ComputerProgramming      0
# ElectronicsAndSemicon    0
# ComputerScience          0
# MechanicalEngg           0
# ElectricalEngg           0
# TelecomEngg              0
# CivilEngg                0
# ...

# %%
Amcat_df.nunique()
# Out:
# Unnamed: 0                  1
# ID                       3998
# Salary                    177
# DOJ                        81
# DOL                        67
# Designation               419
# JobCity                   339
# Gender                      2
# DOB                      1872
# 10percentage              851
# 10board                   275
# 12graduation               16
# 12percentage              801
# 12board                   340
# CollegeID                1350
# CollegeTier                 2
# Degree                      4
# Specialization             46
# collegeGPA               1282
# CollegeCityID            1350
# CollegeCityTier             2
# CollegeState               26
# GraduationYear             11
# English                   111
# Logical                   107
# Quant                     138
# Domain                    243
# ComputerProgramming        79
# ElectronicsAndSemicon      29
# ComputerScience            20
# MechanicalEngg             42
# ...

# %%
Amcat_df = Amcat_df.drop(columns = ['Unnamed: 0', 'ID','CollegeID','CollegeCityID'])
Amcat_df.head()
# Out:
#       Salary          DOJ          DOL               Designation    JobCity  \
# 0   420000.0  6/1/12 0:00      present   senior quality engineer  Bangalore
# 1   500000.0  9/1/13 0:00      present         assistant manager     Indore
# 2   325000.0  6/1/14 0:00      present          systems engineer    Chennai
# 3  1100000.0  7/1/11 0:00      present  senior software engineer    Gurgaon
# 4   200000.0  3/1/14 0:00  3/1/15 0:00                       get    Manesar
#
#   Gender           DOB  10percentage                         10board  \
# 0      f  2/19/90 0:00          84.3  board ofsecondary education,ap
# 1      m  10/4/89 0:00          85.4                            cbse
# 2      f   8/3/92 0:00          85.0                            cbse
# 3      m  12/5/89 0:00          85.6                            cbse
# 4      m  2/27/91 0:00          78.0                            cbse
#
#    12graduation  ...  ComputerScience MechanicalEngg  ElectricalEngg  \
# ...

# %% [markdown]
# # Step 3 - Univariate Numerical Analysis

# %%
sns.boxplot(x=Amcat_df['Salary'])
plt.title('Boxplot of Salary')
plt.show()

# %% [markdown]
# Observation: Outliers in the salary distribution may indicate high-paying jobs in Tier 1 companies or outliers that need investigation.

# %%
sns.histplot(Amcat_df['Salary'], kde=True)
plt.title('Salary Distribution')
plt.show()

# %% [markdown]
# Observation: The salary distribution will show whether most graduates earn within a specific range (e.g., 2.5-3 lakhs).

# %%
axs=plt.subplots(figsize=(10,5))
sns.histplot(Amcat_df['10percentage'])
plt.show()

# %%
axs=plt.subplots(figsize=(10,5))
sns.histplot(Amcat_df['12percentage'])
plt.show()

# %%
axs=plt.subplots(figsize=(10,5))
sns.histplot(Amcat_df['collegeGPA'])
plt.show()

# %% [markdown]
# # Univariate Categorical Analysis

# %%
sns.countplot(x='Gender', data=Amcat_df)
plt.title('Gender Distribution')
plt.show()

# %% [markdown]
# Observation: The countplot will show the frequency of each gender.

# %%
Amcat_df['JobCity'].value_counts().head(20).plot(kind='bar')
plt.title('Job City')
plt.ylabel('Count')
plt.xlabel('Job city')
plt.show()

# %%
Amcat_df['CollegeState'].value_counts().head(20).plot(kind='bar')
plt.title('CollegeState')
plt.ylabel('Count')
plt.xlabel('CollegeState')
plt.show()

# %%
Amcat_df['Specialization'].value_counts().head(20).plot(kind='bar')
plt.title('Top 20 Specializations')
plt.xlabel('Specialization')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Step 4 - Bivariate Analysis

# %%
Amcat_df['GraduationYear']=Amcat_df['GraduationYear'].replace(0,2014)
grad_df=Amcat_df.groupby('GraduationYear')['Salary'].mean().reset_index()
sns.barplot(x='GraduationYear',y='Salary',data=grad_df)
plt.title('Graduation Year vs Salary')
plt.show()

# %%
sns.scatterplot(x='GraduationYear', y='Salary', data=Amcat_df)
plt.title('Salary vs Graduation Year')
plt.show()

# %%
Amcat_df['JobCity'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Job Cities')
# Out:
# Text(0.5, 1.0, 'Top 10 Job Cities')

# %%
Amcat_df['Specialization'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Specializations')
# Out:
# Text(0.5, 1.0, 'Top 10 Specializations')

# %%
plt.hist(Amcat_df['GraduationYear'], bins=5, edgecolor='black')
plt.title('Graduation Year Distribution')
# Out:
# Text(0.5, 1.0, 'Graduation Year Distribution')

# %%
pd.crosstab(Amcat_df['Gender'], Amcat_df['Specialization']).T.plot(kind = 'barh',ec = 'k',figsize = (8,8))
# Out:
# <Axes: ylabel='Specialization'>

# %%
sns.countplot(data=Amcat_df, x='Degree', hue='Gender')
# Out:
# <Axes: xlabel='Degree', ylabel='count'>

# %% [markdown]
# # Step 5 - Research Questions
#
# After doing your Computer Science Engineering if you take up jobs as a Programming Analyst, Software Engineer, Hardware Engineer and Associate Engineer you can earn up to 2.5-3 lakhs as a fresh graduate.

# %%
df1 = Amcat_df[Amcat_df['Designation'].isin(['programmer analyst', 'software engineer', 'hardware engineer', 'associate engineer'])]
df1
# Out:
#         Salary           DOJ           DOL         Designation     JobCity  \
# 19    325000.0   9/1/14 0:00       present   software engineer        Pune
# 20    320000.0  11/1/10 0:00   9/1/12 0:00   software engineer   Bangalore
# 21    200000.0   8/1/12 0:00  12/1/13 0:00   software engineer          -1
# 24    335000.0   6/1/14 0:00   6/1/15 0:00  programmer analyst   Hyderabad
# 31    340000.0   8/1/14 0:00   4/1/15 0:00   software engineer   Bangalore
# ...        ...           ...           ...                 ...         ...
# 3979  550000.0   7/1/13 0:00   4/1/14 0:00   software engineer   Bangalore
# 3981  220000.0   9/1/14 0:00       present   software engineer     Gurgaon
# 3984  480000.0  12/1/11 0:00       present   software engineer     Gurgaon
# 3989  300000.0   9/1/14 0:00       present   software engineer   Bangalore
# 3993  280000.0  10/1/11 0:00  10/1/12 0:00   software engineer  New Delhi
#
#      Gender            DOB  10percentage  \
# ...

# %%
avg_salary=df1['Salary'].mean()
print('Average Salary:',avg_salary)
# Out:
# Average Salary: 339790.4624277457

# %%
max_salary = df1['Salary'].max()
if max_salary >= 250000 and max_salary <= 300000:
    print("The claim that fresh graduates can earn up to 2.5-3 lakhs is supported by the data.")
else:
    print("The claim that fresh graduates can earn up to 2.5-3 lakhs is not supported by the data.")
# Out:
# The claim that fresh graduates can earn up to 2.5-3 lakhs is not supported by the data.

# %%
if avg_salary >= 250000 and avg_salary <= 300000:
    print("The claim that fresh graduates can earn up to 2.5-3 lakhs is supported by the data.")
else:
    print("The claim that fresh graduates can earn up to 2.5-3 lakhs is not supported by the data.")
# Out:
# The claim that fresh graduates can earn up to 2.5-3 lakhs is not supported by the data.

# %%
from scipy.stats import chi2_contingency
contingency_table = pd.crosstab(Amcat_df['Gender'], Amcat_df['Specialization'])
chi2, p, dof, expected = chi2_contingency(contingency_table)
print(f"Chi2 Test Statistic: {chi2}, P-value: {p}")
# Out:
# Chi2 Test Statistic: 104.46891913608455, P-value: 1.2453868176976918e-06

# %% [markdown]
# Observation: If the p-value is more than 0.05, there's no significant relationship between gender and specialization.

# %% [markdown]
# # Step 6 - Conclusion
#
# Univariate Analysis provided insights into the salary distribution, frequency of specializations, and gender distribution.
#
# Bivariate Analysis helped in understanding the relationship between salary and specialization, gender, and roles.
#
# Research Questions:
# Based on the data, the claim that Computer Science engineers earn between 2.5-3 lakhs can be tested, and the result will depend on the average salary of the graduates.
#
# The relationship between gender and specialization can be statistically tested, showing whether certain specializations are more common among a particular gender.
